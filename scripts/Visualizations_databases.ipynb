# %%
import pandas as pd
import tarfile

# %%
gz_file = r"C:\Users\lyach\OneDrive - University of Toronto\PhD\Thesis\Code\catpred-db.tar.gz"

# Extract the .tar.gz file
with tarfile.open(gz_file, "r:gz") as tar:
    tar.extractall(path=r"C:\Users\lyach\OneDrive - University of Toronto\PhD\Thesis\Code\catpred-db.csv")

# %%
# Assuming the extracted CSV file is named 'catpred-db.csv'
csv_file = r"C:\Users\lyach\OneDrive - University of Toronto\PhD\Thesis\Code\catpred-db.csv\CatPred-DB\data\processed_databases\brenda.csv"

# Read the CSV file
df = pd.read_csv(csv_file)

df_kcat = df[df['parameter'] == 'turnover_number']
